# %% [markdown]
# # Hive

# %%
import findspark
findspark.init()

import sys
import subprocess
import logging
from pyspark.sql import SparkSession
from pyspark.sql.functions import col,lit
from pyspark.sql.types import StructType
formatter = logging.Formatter('[%(asctime)s] %(levelname)s @ line %(lineno)d: %(message)s')
handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.INFO)
handler.setFormatter(formatter)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.addHandler(handler)

from pyspark.sql import Row
from pyspark.sql import HiveContext
import pyspark
from IPython.display import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 

from pyspark.sql import Row
from pyspark.sql import HiveContext
import pyspark
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import seaborn as sns
from matplotlib.dates import DateFormatter

# %%
appName= "hive_pyspark"
master= "local"

# %%
spark = SparkSession.builder.master(master).appName(appName).enableHiveSupport().getOrCreate()
# Out:
# 23/01/10 11:46:26 WARN util.Utils: Your hostname, node1 resolves to a loopback address: 127.0.0.1; using 10.0.2.15 instead (on interface enp0s3)
# 23/01/10 11:46:26 WARN util.Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/01/10 11:46:26 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# # Crypto currency comparison in different currencies

# %%
def plot_crypto_comparison(currency):
    crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == '" + str(currency) + "USDT' AND NOT rlike(time, '2023-01-02-*')"))
    crypto_pd = crypto.toPandas()
    time = crypto_pd['time'].values.tolist()
    time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
    DF1 = pd.DataFrame()
    DF1['price'] = crypto_pd['price']
    DF1['time'] = time
    DF1 = DF1.sort_values('time').reset_index(drop = True)

    crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == '" + str(currency) + "GBP' AND NOT rlike(time, '2023-01-02-*')"))
    crypto_pd = crypto.toPandas()
    time = crypto_pd['time'].values.tolist()
    time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
    DF2 = pd.DataFrame()
    DF2['price'] = crypto_pd['price']
    DF2['time'] = time
    DF2 = DF2.sort_values('time').reset_index(drop = True)

    crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == '" + str(currency) + "EUR' AND NOT rlike(time, '2023-01-02-*')"))
    crypto_pd = crypto.toPandas()
    time = crypto_pd['time'].values.tolist()
    time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
    DF3 = pd.DataFrame()
    DF3['price'] = crypto_pd['price']
    DF3['time'] = time
    DF3 = DF3.sort_values('time').reset_index(drop = True)

    date_form = DateFormatter('%d-%m %H:%M')


    fig = plt.figure(figsize = (10, 15))
    ax1 = plt.subplot2grid((8, 1), (0, 0), rowspan=2, colspan=1)
    ax1.tick_params(axis='x', rotation=45)
    ax1.xaxis.set_major_formatter(date_form)

    ax2 = plt.subplot2grid((8, 1), (3, 0), rowspan=2, colspan=1)
    ax2.tick_params(axis='x', rotation=45)
    ax2.xaxis.set_major_formatter(date_form)

    ax3 = plt.subplot2grid((8, 1), (6, 0), rowspan=2, colspan=1)
    ax3.tick_params(axis='x', rotation=45)
    ax3.xaxis.set_major_formatter(date_form)


    p1 = sns.lineplot(data = DF1, x = 'time', y = 'price', ax = ax1)
    p1.set_title(str(currency) + ' price in USD for 2023')
    p1.set_xlabel('Date')
    p1.set_ylabel('Price per unit (USD)')


    p2 = sns.lineplot(data = DF2, x = 'time', y = 'price', ax = ax2)
    p2.set_title(str(currency) +' price in GBP for 2023')
    p2.set_xlabel('Date')
    p2.set_ylabel('Price per unit (GBP)')

    p3 = sns.lineplot(data = DF3, x = 'time', y = 'price', ax = ax3)
    p3.set_title(str(currency) +' price in EUR for 2023')
    p3.set_xlabel('Date')
    p3.set_ylabel('Price per unit (EUR)')

# %%
plot_crypto_comparison('BTC')
# Out:
# 23/01/10 11:46:37 WARN session.SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %% [markdown]
# # Number of Tweets

# %%
tweets = spark.sql("SELECT tweet_count, time FROM twitter_data_test WHERE NOT rlike(time, '2023-01-02-*')")
tweets_pd = tweets.toPandas()
time = tweets_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DFT = pd.DataFrame()
DFT['tweet_count'] = tweets_pd['tweet_count']
DFT['time'] = time
DFT = DFT.sort_values('time').reset_index(drop = True)

date_form = DateFormatter('%d-%m %H:%M')
#date_form = DateFormatter('%Y-%m-%d')


fig = plt.figure(figsize = (10, 3))
ax1 = plt.subplot2grid((1, 1), (0, 0), rowspan=1, colspan=1)
ax1.tick_params(axis='x', rotation=90)
ax1.xaxis.set_major_formatter(date_form)

p1 = sns.lineplot(data = DFT, x = 'time', y = 'tweet_count', ax = ax1)
p1.set_title('Number of tweets including term `crypto`')
p1.set_xlabel('Date')
p1.set_ylabel('Number of tweets')
# Out:
# Text(0, 0.5, 'Number of tweets')

# %% [markdown]
# # Crypto currency dependancy on the number of tweets

# %%
tweets = spark.sql("SELECT tweet_count, time FROM twitter_data_test WHERE NOT rlike(time, '2023-01-02-*')")
tweets_pd = tweets.toPandas()
time = tweets_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DFT = pd.DataFrame()
DFT['tweet_count'] = tweets_pd['tweet_count']
DFT['time'] = time
DFT = DFT.sort_values('time').reset_index(drop = True)

crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == 'BTCUSDT' AND NOT rlike(time, '2023-01-02-*')"))
crypto_pd = crypto.toPandas()
time = crypto_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DF1 = pd.DataFrame()
DF1['price'] = crypto_pd['price']
DF1['time'] = time
DF1 = DF1.sort_values('time').reset_index(drop = True)

crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == 'DOGEUSDT' AND NOT rlike(time, '2023-01-02-*')"))
crypto_pd = crypto.toPandas()
time = crypto_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DF2 = pd.DataFrame()
DF2['price'] = crypto_pd['price']
DF2['time'] = time
DF2 = DF2.sort_values('time').reset_index(drop = True)

crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == 'ETHUSDT' AND NOT rlike(time, '2023-01-02-*')"))
crypto_pd = crypto.toPandas()
time = crypto_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DF3 = pd.DataFrame()
DF3['price'] = crypto_pd['price']
DF3['time'] = time
DF3 = DF3.sort_values('time').reset_index(drop = True)

crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == 'ADAUSDT' AND NOT rlike(time, '2023-01-02-*')"))
crypto_pd = crypto.toPandas()
time = crypto_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DF4 = pd.DataFrame()
DF4['price'] = crypto_pd['price']
DF4['time'] = time
DF4 = DF4.sort_values('time').reset_index(drop = True)

crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == 'XRPUSDT' AND NOT rlike(time, '2023-01-02-*')"))
crypto_pd = crypto.toPandas()
time = crypto_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DF5 = pd.DataFrame()
DF5['price'] = crypto_pd['price']
DF5['time'] = time
DF5 = DF5.sort_values('time').reset_index(drop = True)

crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == 'MATICUSDT' AND NOT rlike(time, '2023-01-02-*')"))
crypto_pd = crypto.toPandas()
time = crypto_pd['time'].values.tolist()
time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
DF6 = pd.DataFrame()
DF6['price'] = crypto_pd['price']
DF6['time'] = time
DF6 = DF6.sort_values('time').reset_index(drop = True)

date_form = DateFormatter('%d-%m %H:%M')


fig = plt.figure(figsize = (10, 20))
axT = plt.subplot2grid((14, 1), (0, 0), rowspan=1, colspan=1)
axT.tick_params(axis='x', rotation = 45)
axT.xaxis.set_major_formatter(date_form)

ax1 = plt.subplot2grid((14, 1), (2, 0), rowspan=1, colspan=1)
ax1.tick_params(axis='x', rotation=45)
ax1.xaxis.set_major_formatter(date_form)

ax2 = plt.subplot2grid((14, 1), (4, 0), rowspan=1, colspan=1)
ax2.tick_params(axis='x', rotation=45)
ax2.xaxis.set_major_formatter(date_form)

ax3 = plt.subplot2grid((14, 1), (6, 0), rowspan=1, colspan=1)
ax3.tick_params(axis='x', rotation=45)
ax3.xaxis.set_major_formatter(date_form)

ax4 = plt.subplot2grid((14, 1), (8, 0), rowspan=1, colspan=1)
ax4.tick_params(axis='x', rotation=45)
ax4.xaxis.set_major_formatter(date_form)

ax5 = plt.subplot2grid((14, 1), (10, 0), rowspan=1, colspan=1)
ax5.tick_params(axis='x', rotation=45)
ax5.xaxis.set_major_formatter(date_form)

ax6 = plt.subplot2grid((14, 1), (12, 0), rowspan=1, colspan=1)
ax6.tick_params(axis='x', rotation=45)
ax6.xaxis.set_major_formatter(date_form)



pT = sns.lineplot(data = DFT, x = 'time', y = 'tweet_count', ax = axT)
pT.set_title('Number of tweets including term `crypto`')
pT.set_xlabel('Date')
pT.set_ylabel('Number of tweets')


p1 = sns.lineplot(data = DF1, x = 'time', y = 'price', ax = ax1)
p1.set_title('BTC price in USD for 2023')
p1.set_xlabel('Date')
p1.set_ylabel('Price per unit (USD)')

p1 = sns.lineplot(data = DF2, x = 'time', y = 'price', ax = ax2)
p1.set_title('DOGE price in USD for 2023')
p1.set_xlabel('Date')
p1.set_ylabel('Price per unit (USD)')

p1 = sns.lineplot(data = DF3, x = 'time', y = 'price', ax = ax3)
p1.set_title('ETH price in USD for 2023')
p1.set_xlabel('Date')
p1.set_ylabel('Price per unit (USD)')

p1 = sns.lineplot(data = DF4, x = 'time', y = 'price', ax = ax4)
p1.set_title('ADA price in USD for 2023')
p1.set_xlabel('Date')
p1.set_ylabel('Price per unit (USD)')

p1 = sns.lineplot(data = DF5, x = 'time', y = 'price', ax = ax5)
p1.set_title('XRP price in USD for 2023')
p1.set_xlabel('Date')
p1.set_ylabel('Price per unit (USD)')

p1 = sns.lineplot(data = DF6, x = 'time', y = 'price', ax = ax6)
p1.set_title('MATIC price in USD for 2023')
p1.set_xlabel('Date')
p1.set_ylabel('Price per unit (USD)')
# Out:
# Text(0, 0.5, 'Price per unit (USD)')

# %% [markdown]
# # Cryptocurrencies correlation

# %%
currencies = pd.DataFrame({'BTC': DF1['price'],'DOGE': DF2['price'],'ETH': DF3['price'],'ADA': DF4['price'],'XRP': DF5['price'],'MATIC': DF6['price'],})
currencies

fig = plt.figure(figsize = (9, 9))
ax1 = plt.subplot2grid((1, 1), (0, 0), rowspan=1, colspan=1)
p1 = sns.heatmap(currencies.corr(), square = False, annot = True, cmap = 'Blues', fmt = 'g', ax = ax1)
p1.set_title('Correlations between cryptocurrencies', fontsize = 30, fontdict = {'weight': 'bold'} )

plt.tight_layout()
plt.show()

# %% [markdown]
# # Cryptocurrency comparison

# %%
def compare_two_cryptos(crypto1, crypto2):
    crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == '" + str(crypto1) + "USDT' AND NOT rlike(time, '2023-01-02-*')"))
    crypto_pd = crypto.toPandas()
    time = crypto_pd['time'].values.tolist()
    time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
    DF1 = pd.DataFrame()
    DF1['price'] = crypto_pd['price']
    DF1['time'] = time
    DF1 = DF1.sort_values('time').reset_index(drop = True)

    crypto = spark.sql(str("SELECT * FROM crypto_data_test WHERE symbol == '" + str(crypto2) + "USDT' AND NOT rlike(time, '2023-01-02-*')"))
    crypto_pd = crypto.toPandas()
    time = crypto_pd['time'].values.tolist()
    time = pd.to_datetime(time, format='%Y-%m-%d-%H-%M-%S')
    DF2 = pd.DataFrame()
    DF2['price'] = crypto_pd['price']
    DF2['time'] = time
    DF2 = DF2.sort_values('time').reset_index(drop = True)
    
    date_form = DateFormatter('%d-%m %H:%M')

    fig = plt.figure(figsize = (10, 10))

    ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan=3, colspan=1)
    ax1.tick_params(axis='x', rotation=45)
    ax1.xaxis.set_major_formatter(date_form)

    ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan=3, colspan=1)
    ax2.tick_params(axis='x', rotation=45)
    ax2.xaxis.set_major_formatter(date_form)
    
    p1 = sns.lineplot(data = DF1, x = 'time', y = 'price', ax = ax1)
    p1.set_title(crypto1 + ' price in USD for 2023')
    p1.set_xlabel('Date')
    p1.set_ylabel('Price per unit (USD)')

    p1 = sns.lineplot(data = DF2, x = 'time', y = 'price', ax = ax2)
    p1.set_title(crypto2 + ' price in USD for 2023')
    p1.set_xlabel('Date')
    p1.set_ylabel('Price per unit (USD)')

# %%
compare_two_cryptos('BTC', 'ETH')

# %% [markdown]
# # HBase

# %%
import happybase

# %%
VM_address = 'localhost'#'vl39.mini.pw.edu.pl'
connection = happybase.Connection(VM_address, port=9090)
table = connection.table('projekt_test')
scanner = table.scan()
for t in scanner:
    print(t)
# Out:
# (b'crypto_data_0', {b'price_data:price': b'17268.330078125', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_1', {b'price_data:price': b'1332.8699951171875', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_10', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_100', {b'price_data:price': b'0.06300999969244003', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_101', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_102', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_103', {b'price_data:price': b'0.7914000153541565', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_104', {b'price_data:price': b'0.6976000070571899', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_105', {b'price_data:price': b'17266.240234375', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_106', {b'price_data:price': b'1332.81005859375', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_107', {b'price_data:price': b'0.3192000091075897', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_108', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_109', {b'price_data:price': b'0.8489000201225281', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_11', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_110', {b'price_data:price': b'0.07665000110864639', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_111', {b'price_data:price': b'16088.23046875', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_112', {b'price_data:price': b'1242.0799560546875', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_113', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_114', {b'price_data:price': b'14188.3798828125', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_115', {b'price_data:price': b'1095.3199462890625', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_116', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_117', {b'price_data:price': b'4.921999931335449', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_118', {b'price_data:price': b'4.585000038146973', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_119', {b'price_data:price': b'0.29760000109672546', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_12', {b'price_data:price': b'4.923999786376953', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_120', {b'price_data:price': b'0.07143999636173248', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_121', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_122', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_123', {b'price_data:price': b'0.2623000144958496', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_124', {b'price_data:price': b'0.7914999723434448', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_125', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-49-52', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_126', {b'price_data:price': b'17265.4609375', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_127', {b'price_data:price': b'1332.81005859375', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_128', {b'price_data:price': b'0.3192000091075897', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_129', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_13', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_130', {b'price_data:price': b'0.848800003528595', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_131', {b'price_data:price': b'0.07664000242948532', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_132', {b'price_data:price': b'16089.580078125', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_133', {b'price_data:price': b'1242.0799560546875', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_134', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_135', {b'price_data:price': b'14191.8095703125', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_136', {b'price_data:price': b'1095.3199462890625', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_137', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_138', {b'price_data:price': b'4.921999931335449', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_139', {b'price_data:price': b'4.585000038146973', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_14', {b'price_data:price': b'0.29829999804496765', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_140', {b'price_data:price': b'0.29760000109672546', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_141', {b'price_data:price': b'0.07143999636173248', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_142', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_143', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_144', {b'price_data:price': b'0.2623000144958496', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_145', {b'price_data:price': b'0.7914999723434448', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_146', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-50-07', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_147', {b'price_data:price': b'17267.130859375', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_148', {b'price_data:price': b'1332.81005859375', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_149', {b'price_data:price': b'0.3192000091075897', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_15', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_150', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_151', {b'price_data:price': b'0.8486999869346619', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_152', {b'price_data:price': b'0.07666999846696854', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_153', {b'price_data:price': b'16089.0703125', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_154', {b'price_data:price': b'1242.0699462890625', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_155', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_156', {b'price_data:price': b'14191.1796875', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_157', {b'price_data:price': b'1095.3199462890625', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_158', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_159', {b'price_data:price': b'4.921999931335449', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_16', {b'price_data:price': b'0.06300999969244003', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_160', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_161', {b'price_data:price': b'0.29760000109672546', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_162', {b'price_data:price': b'0.07143999636173248', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_163', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_164', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_165', {b'price_data:price': b'0.2623000144958496', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_166', {b'price_data:price': b'0.791100025177002', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_167', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-50-22', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_168', {b'price_data:price': b'17270.259765625', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_169', {b'price_data:price': b'1333.0400390625', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_17', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_170', {b'price_data:price': b'0.3197000026702881', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_171', {b'price_data:price': b'0.35010001063346863', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_172', {b'price_data:price': b'0.849399983882904', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_173', {b'price_data:price': b'0.07672999799251556', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_174', {b'price_data:price': b'16090.2998046875', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_175', {b'price_data:price': b'1242.1300048828125', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_176', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_177', {b'price_data:price': b'14193.5302734375', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_178', {b'price_data:price': b'1095.3199462890625', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_179', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_18', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_180', {b'price_data:price': b'4.925000190734863', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_181', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_182', {b'price_data:price': b'0.2980000078678131', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_183', {b'price_data:price': b'0.07143999636173248', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_184', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_185', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_186', {b'price_data:price': b'0.2623000144958496', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_187', {b'price_data:price': b'0.791100025177002', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_188', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-50-53', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_189', {b'price_data:price': b'17268.560546875', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_19', {b'price_data:price': b'0.7914000153541565', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_190', {b'price_data:price': b'1332.9100341796875', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_191', {b'price_data:price': b'0.3199999928474426', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_192', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_193', {b'price_data:price': b'0.8489000201225281', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_194', {b'price_data:price': b'0.07673999667167664', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_195', {b'price_data:price': b'16092.759765625', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_196', {b'price_data:price': b'1242.1700439453125', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_197', {b'price_data:price': b'0.3260999917984009', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_198', {b'price_data:price': b'14193.4501953125', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_199', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_2', {b'price_data:price': b'0.32010000944137573', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_20', {b'price_data:price': b'0.6976000070571899', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_200', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_201', {b'price_data:price': b'4.923999786376953', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_202', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_203', {b'price_data:price': b'0.29820001125335693', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_204', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_205', {b'price_data:price': b'0.06300999969244003', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_206', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_207', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_208', {b'price_data:price': b'0.7914000153541565', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_209', {b'price_data:price': b'0.6976000070571899', b'price_data:time': b'2023-01-10-10-52-42', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_21', {b'price_data:price': b'17270.869140625', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_210', {b'price_data:price': b'17270.669921875', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_211', {b'price_data:price': b'1333.02001953125', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_212', {b'price_data:price': b'0.3199999928474426', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_213', {b'price_data:price': b'0.3499000072479248', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_214', {b'price_data:price': b'0.849399983882904', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_215', {b'price_data:price': b'0.07673999667167664', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_216', {b'price_data:price': b'16091.150390625', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_217', {b'price_data:price': b'1242.02001953125', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_218', {b'price_data:price': b'0.326200008392334', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_219', {b'price_data:price': b'14193.5', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_22', {b'price_data:price': b'1333.02001953125', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_220', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_221', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_222', {b'price_data:price': b'4.925000190734863', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_223', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_224', {b'price_data:price': b'0.29809999465942383', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_225', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_226', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_227', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_228', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_229', {b'price_data:price': b'0.791100025177002', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_23', {b'price_data:price': b'0.3199000060558319', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_230', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-51-23', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_231', {b'price_data:price': b'17270.400390625', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_232', {b'price_data:price': b'1333.02001953125', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_233', {b'price_data:price': b'0.3199999928474426', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_234', {b'price_data:price': b'0.3499000072479248', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_235', {b'price_data:price': b'0.849399983882904', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_236', {b'price_data:price': b'0.0767500028014183', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_237', {b'price_data:price': b'16090.5400390625', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_238', {b'price_data:price': b'1242.3299560546875', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_239', {b'price_data:price': b'0.326200008392334', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_24', {b'price_data:price': b'0.3499000072479248', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_240', {b'price_data:price': b'14194.919921875', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_241', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_242', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_243', {b'price_data:price': b'4.923999786376953', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_244', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_245', {b'price_data:price': b'0.29829999804496765', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_246', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_247', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_248', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_249', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_25', {b'price_data:price': b'0.8493000268936157', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_250', {b'price_data:price': b'0.7914999723434448', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_251', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-51-54', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_252', {b'price_data:price': b'17270.439453125', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_253', {b'price_data:price': b'1333.010009765625', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_254', {b'price_data:price': b'0.3199999928474426', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_255', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_256', {b'price_data:price': b'0.849399983882904', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_257', {b'price_data:price': b'0.0767500028014183', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_258', {b'price_data:price': b'16091.150390625', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_259', {b'price_data:price': b'1242.02001953125', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_26', {b'price_data:price': b'0.07671999931335449', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_260', {b'price_data:price': b'0.326200008392334', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_261', {b'price_data:price': b'14194.91015625', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_262', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_263', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_264', {b'price_data:price': b'4.925000190734863', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_265', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_266', {b'price_data:price': b'0.29820001125335693', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_267', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_268', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_269', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_27', {b'price_data:price': b'16092.91015625', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_270', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_271', {b'price_data:price': b'0.791100025177002', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_272', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-51-38', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_273', {b'price_data:price': b'17270.51953125', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_274', {b'price_data:price': b'1333.010009765625', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_275', {b'price_data:price': b'0.3199999928474426', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_276', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_277', {b'price_data:price': b'0.849399983882904', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_278', {b'price_data:price': b'0.07673999667167664', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_279', {b'price_data:price': b'16093.08984375', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_28', {b'price_data:price': b'1242.010009765625', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_280', {b'price_data:price': b'1242.18994140625', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_281', {b'price_data:price': b'0.3260999917984009', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_282', {b'price_data:price': b'14194.330078125', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_283', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_284', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_285', {b'price_data:price': b'4.925000190734863', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_286', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_287', {b'price_data:price': b'0.29820001125335693', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_288', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_289', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_29', {b'price_data:price': b'0.326200008392334', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_290', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_291', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_292', {b'price_data:price': b'0.7914999723434448', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_293', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-52-10', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_3', {b'price_data:price': b'0.3499000072479248', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_30', {b'price_data:price': b'14194.23046875', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_31', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_32', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_33', {b'price_data:price': b'4.925000190734863', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_34', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_35', {b'price_data:price': b'0.29829999804496765', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_36', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_37', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_38', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_39', {b'price_data:price': b'0.2630999982357025', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_4', {b'price_data:price': b'0.8489999771118164', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_40', {b'price_data:price': b'0.791100025177002', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_41', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-51-08', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_42', {b'price_data:price': b'17264.91015625', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_43', {b'price_data:price': b'1332.81005859375', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_44', {b'price_data:price': b'0.31929999589920044', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_45', {b'price_data:price': b'0.3499000072479248', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_46', {b'price_data:price': b'0.8489999771118164', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_47', {b'price_data:price': b'0.07664000242948532', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_48', {b'price_data:price': b'16090.240234375', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_49', {b'price_data:price': b'1242.0799560546875', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_5', {b'price_data:price': b'0.07673999667167664', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_50', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_51', {b'price_data:price': b'14191.169921875', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_52', {b'price_data:price': b'1095.3199462890625', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_53', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_54', {b'price_data:price': b'4.921999931335449', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_55', {b'price_data:price': b'4.585000038146973', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_56', {b'price_data:price': b'0.29760000109672546', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_57', {b'price_data:price': b'0.0713300034403801', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_58', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_59', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_6', {b'price_data:price': b'16094.41015625', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_60', {b'price_data:price': b'0.2623000144958496', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_61', {b'price_data:price': b'0.7914999723434448', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_62', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-49-37', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_63', {b'price_data:price': b'17268.44921875', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_64', {b'price_data:price': b'1333.0', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_65', {b'price_data:price': b'0.31940001249313354', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_66', {b'price_data:price': b'0.35010001063346863', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_67', {b'price_data:price': b'0.8490999937057495', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_68', {b'price_data:price': b'0.07667999714612961', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_69', {b'price_data:price': b'16089.83984375', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_7', {b'price_data:price': b'1242.0799560546875', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_70', {b'price_data:price': b'1242.0699462890625', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_71', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_72', {b'price_data:price': b'14192.5498046875', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_73', {b'price_data:price': b'1095.3199462890625', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_74', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_75', {b'price_data:price': b'4.923999786376953', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_76', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_77', {b'price_data:price': b'0.29750001430511475', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_78', {b'price_data:price': b'0.07143999636173248', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})
# (b'crypto_data_79', {b'price_data:price': b'0.06300000101327896', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOGEGBP'})
# (b'crypto_data_8', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_80', {b'price_data:price': b'4.039999961853027', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'DOTGBP'})
# (b'crypto_data_81', {b'price_data:price': b'0.2623000144958496', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ADAGBP'})
# (b'crypto_data_82', {b'price_data:price': b'0.791100025177002', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'MATICEUR'})
# (b'crypto_data_83', {b'price_data:price': b'0.6974999904632568', b'price_data:time': b'2023-01-10-10-50-37', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'MATICGBP'})
# (b'crypto_data_84', {b'price_data:price': b'17268.939453125', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'BTCUSDT'})
# (b'crypto_data_85', {b'price_data:price': b'1332.9100341796875', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ETHUSDT'})
# (b'crypto_data_86', {b'price_data:price': b'0.3199000060558319', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'ADAUSDT'})
# (b'crypto_data_87', {b'price_data:price': b'0.3499999940395355', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'XRPUSDT'})
# (b'crypto_data_88', {b'price_data:price': b'0.8489000201225281', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'MATIC', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'MATICUSDT'})
# (b'crypto_data_89', {b'price_data:price': b'0.07672999799251556', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOGEUSDT'})
# (b'crypto_data_9', {b'price_data:price': b'14193.4501953125', b'price_data:time': b'2023-01-10-10-52-57', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_90', {b'price_data:price': b'16092.9599609375', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'BTCEUR'})
# (b'crypto_data_91', {b'price_data:price': b'1242.1700439453125', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ETHEUR'})
# (b'crypto_data_92', {b'price_data:price': b'0.3262999951839447', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'XRPEUR'})
# (b'crypto_data_93', {b'price_data:price': b'14192.400390625', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'BTC', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'BTCGBP'})
# (b'crypto_data_94', {b'price_data:price': b'1095.3900146484375', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'ETH', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'ETHGBP'})
# (b'crypto_data_95', {b'price_data:price': b'0.28769999742507935', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'XRP', b'symbols:symbol_2': b'GBP', b'symbols:trade_symbol': b'XRPGBP'})
# (b'crypto_data_96', {b'price_data:price': b'4.923999786376953', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'USDT', b'symbols:trade_symbol': b'DOTUSDT'})
# (b'crypto_data_97', {b'price_data:price': b'4.585999965667725', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'DOT', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOTEUR'})
# (b'crypto_data_98', {b'price_data:price': b'0.29820001125335693', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'ADA', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'ADAEUR'})
# (b'crypto_data_99', {b'price_data:price': b'0.07151000201702118', b'price_data:time': b'2023-01-10-10-52-26', b'symbols:symbol_1': b'DOGE', b'symbols:symbol_2': b'EUR', b'symbols:trade_symbol': b'DOGEEUR'})

# %%
def create_table(crypto):
    print('Acessing the data')
    connection = happybase.Connection(VM_address, port = 9090)
    table = connection.table('projekt_test')
    columns = [b'price_data:price', b'price_data:time', b'symbols:symbol_1', b'symbols:symbol_2', b'symbols:trade_symbol']
    columns = [str(c, 'UTF-8') for c in columns]
    x = {}
    for c in columns:
        x[c] = []
    output_df = pd.DataFrame(x)
    i = 0
    
    for key, data in table.scan(columns = columns):
        d = {}
        for column, value in data.items():
            if str(column, 'UTF-8') == 'symbols:trade_symbol' and str(value, 'UTF-8') == crypto:
                i = len(columns) - 1
            i -= 1
            if str(column, 'UTF-8') == 'price_data:price':
                d[str(column, 'UTF-8')] = [float(value)]
            else:
                d[str(column, 'UTF-8')] = [str(value, 'UTF-8')]
        if i > 0:
            dataframe = pd.DataFrame.from_dict(d, orient='columns')
            dataframe = dataframe[columns]
            output_df = pd.concat([output_df, dataframe])
            
    return output_df

# %%
BTCUSDT  = create_table('BTCUSDT')['price_data:price']
ETHUSDT  = create_table('ETHUSDT')['price_data:price']
DOGEUSDT = create_table('DOGEUSDT')['price_data:price']
DOTUSDT  = create_table('DOTUSDT')['price_data:price']
XRPUSDT  = create_table('XRPUSDT')['price_data:price']
ADAUSDT  = create_table('ADAUSDT')['price_data:price']
Crypto   = ['BTCUSDT', 'ETHUSDT', 'DOGEUSDT', 'DOTUSDT', 'XRPUSDT', 'ADAUSDT']
Min      = [BTCUSDT.min(), ETHUSDT.min(), DOGEUSDT.min(), DOTUSDT.min(), XRPUSDT.min(), ADAUSDT.min()]
Min_rel  = [BTCUSDT.min() / BTCUSDT.mean(), DOGEUSDT.min() / DOGEUSDT.mean(), DOGEUSDT.min() / DOGEUSDT.mean(), DOTUSDT.min() / DOTUSDT.mean(), XRPUSDT.min() / XRPUSDT.mean(), ADAUSDT.min() / ADAUSDT.mean()]
Mean     = [BTCUSDT.mean(), ETHUSDT.mean(), DOGEUSDT.mean(), DOTUSDT.mean(), XRPUSDT.mean(), ADAUSDT.mean()]
Max_rel  = [BTCUSDT.max() / BTCUSDT.mean(), DOGEUSDT.max() / DOGEUSDT.mean(), DOGEUSDT.max() / DOGEUSDT.mean(), DOTUSDT.max() / DOTUSDT.mean(), XRPUSDT.max() / XRPUSDT.mean(), ADAUSDT.max() / ADAUSDT.mean()]
Max      = [BTCUSDT.max(), ETHUSDT.max(), DOGEUSDT.max(), DOTUSDT.max(), XRPUSDT.max(), ADAUSDT.max()]

Diff_analysis = pd.DataFrame({'Crypto': Crypto, 'Min': Min, 'Min_rel': Min_rel, 'Mean': Mean, 'Max': Max, 'Max_rel': Max_rel,})
Diff_analysis
# Out:
# Acessing the data
# Acessing the data
# Acessing the data
# Acessing the data
# Acessing the data
# Acessing the data
#      Crypto           Min   Min_rel          Mean           Max   Max_rel
# 0   BTCUSDT  17264.910156  0.999783  17268.655692  17270.869141  1.000128
# 1   ETHUSDT   1332.810059  0.999106   1332.932173   1333.040039  1.000540
# 2  DOGEUSDT      0.076640  0.999106      0.076709      0.076750  1.000540
# 3   DOTUSDT      4.922000  0.999637      4.923786      4.925000  1.000247
# 4   XRPUSDT      0.349900  0.999776      0.349979      0.350100  1.000347
# 5   ADAUSDT      0.319200  0.998414      0.319707      0.320100  1.001229
